% %% [markdown]
% ## Recuperation des paramètres libres
%
% Cette procedure represente une étape fondamentale pour pouvoir intérpreter les valeurs estimés des parametres libres. Elle consiste dans une évaluation de la qualité de la procedure d'estimation.
%
% La procedure est très simple et consiste en deux étapes:
%
% -  D'abord on simule les choix du modèle avec des parametres que on choisit.
%
% -  Ensuite on donne les choix du modèle à notre processus d'estimation et on voit à quel point les parametres estimé correspond au paramètres que nous avons utilisé pour faire la simulation
%
% Comme le processus est stochastique, c'est normale d'avoir une correspondance non parfaitment exacte entre les parametètres utilisés pour engendrer les simulations et les parametrès estimées, donc nous allons répétér le processus plusieurs fois pour évaluer la qualité du processus d'estimation sur la base de plusiers points.

% %% [markdown]
% ## Code
%
% Comme dans le code pour l'estimation, aussi dans cette partie nous ferons appelle à deux fonctions:
%
% - dans le dossier "my_models" : il y a une fonction qui s'appelle `Qmodel`, qui produit des choix simulés du modèle avec certains paramètres libres (alpha et inv_temp) et certaines caractéristiques de la tâche expérimentale comme le nombre d'essais (`ntrials`) et le nombre de blocs d'apprentissage (`nruns`)..
%
% - dans le dossier "my_functions" : il y a une fonction qui s'appelle `estimateQ_gridsearch` qui exécute le grid search pour trouver les meilleures valeurs des paramètres libres du Qmodel, étant donné les choix (`ch`) et l'historique des récompenses obtenues (`r`) ainsi que les caractéristiques de la tâche (`nruns`) d'un certain participant.
%
%
% ### Definire ou trouver les fonctions

% %%
here = pwd
addpath(genpath(fullfile(here,'my_models')));
addpath(genpath(fullfile(here,'my_functions')));
% Out:
% here = '/Users/pool/Documents/Teaching/PA/AdvanceSignal/code/4-recuperer_parametres'

% %% [markdown]
% ### Définir les variables "input"
%
% Ici au début du code nous allons définir les variables que nous voulons facilement modifer

% %%
nsub    = 300; % nombre de participants
ntrials = 100; % nombre d'essais
nruns   =  10; % nombre de bloques d'apprentissage

% %% [markdown]
% ### Initialiser les variables "output"
%
% Ici nous allons initialiser des matrices vides (NaN) dans lesquelles nous allons sauvgarder les résultats des notre processsus.

% %%
simulated_param = nan(nsub,2);
recovered_param = nan(nsub,2);

% %% [markdown]
% ### Définir les variables du processus d'estimation
%
% Ici nous allons définir variables pour le processus d'estimation des parametres qui utilise la fonction d'optimisation *fmincon*

% %%
% nombre de point initial (e.g., combinaison de valeur de parametres libres) dans lequel la fonction 
% d'optimisation va commencer
nstarts = 5;

% definition des valeurs limites de nos deux parametres
xmin    = [0 0]; % Min : première colonne temperature et deuxième colonne alpha
xmax    = [5 1]; % Max : première colonne temperature et deuxième colonne alpha

% ici on définit les options spécifiques à fmincon
options = optimset('Algorithm', 'interior-point', 'Display', 'iter-detailed', 'MaxIter', 10000, 'Display','off'); % These increase the number of iterations to ensure the convergence
warning off all

% %% [markdown]
% ### Définir les distributions des paramètres libres pour les simulations
%
% Nous devons choisir plusiers valuers du taux d'apprentissage $\alpha$ et de la temperature $\beta$, pour ce faire nous allons pas pêcher complètament au hasard, mais nous allons suivre des distributions dans lesquelles certain valeurs des parametres seront plus souvant choisit que d'autres.

% %% [markdown]
% - **Pour la temperature inverse ($\beta$)**: Le plus ce valeur est grand, le plus les gens explorent les effects de choisir l'option qui a le moins de valuer, selon la base des études précedant, nous savons que les gens explore un peu, mais mais pas tout le temps, donc nous utilison une distribution gamma qui determine que les valuers le plus choisit sont les moins elevées. La distribution gamma varie selon deux de paramètre: la forme $ k $ et l' échelle $\theta$ . Dans le code ci-dessous vous pouvez modifier les paramètre de la fonction gamma pour voir les effects sur la distribution de la densité de probabilité.

% %%
% graphique de la distrubtion pour la temperature

x = 0:0.01:5;  

forme   = 1.5;
echelle = 1;

distr_tp = gampdf(x, forme, echelle);

figure

plot(x, distr_tp, 'Color', .2 * [1, 1, 1], 'LineWidth',2)
xlabel('Valeurs de la temperature');  % x-axis label
ylabel('Densité de probabilité');  % y-axis label

grid on;

% %% [markdown]
% Pour notre boucle de simulation nous voulons cette ristribution mais contrainte entre les valeurs maximales et minimales

% %%
pd = makedist('Gamma',1.2,1.2);      % definir la ristribution pour la temperature 
temp_pdt = truncate(pd,xmin(1),xmax(1))  % contraindre la distribution par les min et max de la temperature
% Out:
% temp_pdt =
%   <a href="matlab: helpPopup prob.GammaDistribution">GammaDistribution</a>
%
%   Gamma distribution
%     a = 1.2
%     b = 1.2
%   Truncated to the interval [0, 5]

% %% [markdown]
% - **Pour la taux d'apprentissage ($\alpha$)**: Sur la base des études passés nous savons que c'est extremement rare que les gens n'intégrent pas du tout l'erreur de prédiction dans la mis à jours de la valeur ($\alpha = 0$) ou que les gens oublient l'estimation de la valuer précedant et utilisent la valuer de l'erreur de prédiction de manière instantanée ($\alpha = 1$). Nous allons utiliser une distribution bêta. La loi bêta est une distribution de probabilité continue définie sur l'intervalle $[0,1]$. La forme de la loi bêta dépend de deux paramètres $\alpha$ et $\beta$ (attention ils ont les même noms mais il ne correspond pas aux paramètres libres de notre Qmodel) qui contrôlent la forme de la distribution de la densisté de probabilité.  Dans le code ci-dessous vous pouvez modifier ces paramètres pour voir les effects sur la distribution.

% %%
% graphique de la distrubution pour le taux d'apprentissage

x = 0:0.01:1;  
beta_alpha = 2.5;
beta_beta  = 2.5;
distr_tp = betapdf(x, beta_alpha,beta_beta);

figure

plot(x, distr_tp, 'Color', .2 * [1, 1, 1], 'LineWidth',2)
xlabel('Valeurs de du taux d''apprentissage');  % x-axis label
ylabel('Densité de probabilité');               % y-axis label

grid on;

% %% [markdown]
% ## Boucle pour la simulation et et estimation de plusieurs paramètres libres
%
% Ici pour le nombre de participants que nous avons détérminé au début du script, nous allons:
%
% - tirer les paramètres des distributions que nous avons décrit au préalable.
% - sauver les paramètres (temperature et taux d'apprentissage) dans une matrice.
% - simuler les choix du modèle avec ces paramètres (e.g., le participant sythetique).
% - estimer les paramètres libres sur la base du comportement du participant sythetique. Cela nous le faisons plusieurs fois (nstarts) avec à chaque fois des points initial pour le search différent. Ensuite nous allons selectioner les paramètres qui ont engendré la plus petite vraisemblance négative.
% - sauver les paramètres estimées.

% %%
for ksub = 1:nsub


    disp (['-------  synthetic participant  ' num2str(ksub) '   -------']);


    % Tirer les paramètres des distributions
    sim_param(ksub).alpha     = random('Beta', 2.5, 2.5);% beta est déjà entre 0 et 1 donc nous n'avons pas besoin de contraindre
    sim_param(ksub).inv_temp  = random(temp_pdt);

    % sauver les valeurs de parametrès que nous avons seléctionné
    simulated_param(ksub,:) = [sim_param(ksub).inv_temp,sim_param(ksub).alpha];

    % simuler le participant sythetitque
    [sim_ch, sim_r] = Qmodel(sim_param(ksub).alpha, sim_param(ksub).inv_temp, ntrials, nruns);

    % estimate free parameters
    nll = nan(nstarts,1); % initialiser un vecteur vide pour sauver la vraisemblance négative
    
    for strt = 1:nstarts % essayer plusieurs recherche avec des différentes de points initial

        x0 = unifrnd(xmin,xmax); % tirer au hasard les points initiaux entre les limites définie
    
        % executer la fonction d'optimisation et sauver la vraisamblence négative et les paramétres estimées
        [rec_param(strt,:),nll(strt),~,~,~] = fmincon(@(x) estimateQ(x,sim_ch,sim_r, nruns),x0,[],[],[],[],xmin,xmax,[],options);

    end

    % trouver le min loglike avec les different paramentres
    minnLL = find(min(nll));

    recovered_param(ksub,:) = rec_param (minnLL,:);

end
% Out:
% -------  synthetic participant  1   -------
% -------  synthetic participant  2   -------
% -------  synthetic participant  3   -------
% -------  synthetic participant  4   -------
% -------  synthetic participant  5   -------
% -------  synthetic participant  6   -------
% -------  synthetic participant  7   -------
% -------  synthetic participant  8   -------
% -------  synthetic participant  9   -------
% -------  synthetic participant  10   -------
% -------  synthetic participant  11   -------
% -------  synthetic participant  12   -------
% -------  synthetic participant  13   -------
% -------  synthetic participant  14   -------
% -------  synthetic participant  15   -------
% -------  synthetic participant  16   -------
% -------  synthetic participant  17   -------
% -------  synthetic participant  18   -------
% -------  synthetic participant  19   -------
% -------  synthetic participant  20   -------
% -------  synthetic participant  21   -------
% -------  synthetic participant  22   -------
% -------  synthetic participant  23   -------
% -------  synthetic participant  24   -------
% -------  synthetic participant  25   -------
% -------  synthetic participant  26   -------
% -------  synthetic participant  27   -------
% -------  synthetic participant  28   -------
% -------  synthetic participant  29   -------
% -------  synthetic participant  30   -------
% -------  synthetic participant  31   -------
% -------  synthetic participant  32   -------
% -------  synthetic participant  33   -------
% -------  synthetic participant  34   -------
% -------  synthetic participant  35   -------
% -------  synthetic participant  36   -------
% -------  synthetic participant  37   -------
% -------  synthetic participant  38   -------
% -------  synthetic participant  39   -------
% -------  synthetic participant  40   -------
% -------  synthetic participant  41   -------
% -------  synthetic participant  42   -------
% -------  synthetic participant  43   -------
% -------  synthetic participant  44   -------
% -------  synthetic participant  45   -------
% -------  synthetic participant  46   -------
% -------  synthetic participant  47   -------
% -------  synthetic participant  48   -------
% -------  synthetic participant  49   -------
% -------  synthetic participant  50   -------
% -------  synthetic participant  51   -------
% -------  synthetic participant  52   -------
% -------  synthetic participant  53   -------
% -------  synthetic participant  54   -------
% -------  synthetic participant  55   -------
% -------  synthetic participant  56   -------
% -------  synthetic participant  57   -------
% -------  synthetic participant  58   -------
% -------  synthetic participant  59   -------
% -------  synthetic participant  60   -------
% -------  synthetic participant  61   -------
% -------  synthetic participant  62   -------
% -------  synthetic participant  63   -------
% -------  synthetic participant  64   -------
% -------  synthetic participant  65   -------
% -------  synthetic participant  66   -------
% -------  synthetic participant  67   -------
% -------  synthetic participant  68   -------
% -------  synthetic participant  69   -------
% -------  synthetic participant  70   -------
% -------  synthetic participant  71   -------
% -------  synthetic participant  72   -------
% -------  synthetic participant  73   -------
% -------  synthetic participant  74   -------
% -------  synthetic participant  75   -------
% -------  synthetic participant  76   -------
% -------  synthetic participant  77   -------
% -------  synthetic participant  78   -------
% -------  synthetic participant  79   -------
% -------  synthetic participant  80   -------
% -------  synthetic participant  81   -------
% -------  synthetic participant  82   -------
% -------  synthetic participant  83   -------
% -------  synthetic participant  84   -------
% -------  synthetic participant  85   -------
% -------  synthetic participant  86   -------
% -------  synthetic participant  87   -------
% -------  synthetic participant  88   -------
% -------  synthetic participant  89   -------
% -------  synthetic participant  90   -------
% -------  synthetic participant  91   -------
% -------  synthetic participant  92   -------
% -------  synthetic participant  93   -------
% -------  synthetic participant  94   -------
% -------  synthetic participant  95   -------
% -------  synthetic participant  96   -------
% -------  synthetic participant  97   -------
% -------  synthetic participant  98   -------
% -------  synthetic participant  99   -------
% -------  synthetic participant  100   -------
% -------  synthetic participant  101   -------
% -------  synthetic participant  102   -------
% -------  synthetic participant  103   -------
% -------  synthetic participant  104   -------
% -------  synthetic participant  105   -------
% -------  synthetic participant  106   -------
% -------  synthetic participant  107   -------
% -------  synthetic participant  108   -------
% -------  synthetic participant  109   -------
% -------  synthetic participant  110   -------
% -------  synthetic participant  111   -------
% -------  synthetic participant  112   -------
% -------  synthetic participant  113   -------
% -------  synthetic participant  114   -------
% -------  synthetic participant  115   -------
% -------  synthetic participant  116   -------
% -------  synthetic participant  117   -------
% -------  synthetic participant  118   -------
% -------  synthetic participant  119   -------
% -------  synthetic participant  120   -------
% -------  synthetic participant  121   -------
% -------  synthetic participant  122   -------
% -------  synthetic participant  123   -------
% -------  synthetic participant  124   -------
% -------  synthetic participant  125   -------
% -------  synthetic participant  126   -------
% -------  synthetic participant  127   -------
% -------  synthetic participant  128   -------
% -------  synthetic participant  129   -------
% -------  synthetic participant  130   -------
% -------  synthetic participant  131   -------
% -------  synthetic participant  132   -------
% -------  synthetic participant  133   -------
% -------  synthetic participant  134   -------
% -------  synthetic participant  135   -------
% -------  synthetic participant  136   -------
% -------  synthetic participant  137   -------
% -------  synthetic participant  138   -------
% -------  synthetic participant  139   -------
% -------  synthetic participant  140   -------
% -------  synthetic participant  141   -------
% -------  synthetic participant  142   -------
% -------  synthetic participant  143   -------
% -------  synthetic participant  144   -------
% -------  synthetic participant  145   -------
% -------  synthetic participant  146   -------
% -------  synthetic participant  147   -------
% -------  synthetic participant  148   -------
% -------  synthetic participant  149   -------
% -------  synthetic participant  150   -------
% -------  synthetic participant  151   -------
% -------  synthetic participant  152   -------
% -------  synthetic participant  153   -------
% -------  synthetic participant  154   -------
% -------  synthetic participant  155   -------
% -------  synthetic participant  156   -------
% -------  synthetic participant  157   -------
% -------  synthetic participant  158   -------
% -------  synthetic participant  159   -------
% -------  synthetic participant  160   -------
% -------  synthetic participant  161   -------
% -------  synthetic participant  162   -------
% -------  synthetic participant  163   -------
% -------  synthetic participant  164   -------
% -------  synthetic participant  165   -------
% -------  synthetic participant  166   -------
% -------  synthetic participant  167   -------
% -------  synthetic participant  168   -------
% -------  synthetic participant  169   -------
% -------  synthetic participant  170   -------
% -------  synthetic participant  171   -------
% -------  synthetic participant  172   -------
% -------  synthetic participant  173   -------
% -------  synthetic participant  174   -------
% -------  synthetic participant  175   -------
% -------  synthetic participant  176   -------
% -------  synthetic participant  177   -------
% -------  synthetic participant  178   -------
% -------  synthetic participant  179   -------
% -------  synthetic participant  180   -------
% -------  synthetic participant  181   -------
% -------  synthetic participant  182   -------
% -------  synthetic participant  183   -------
% -------  synthetic participant  184   -------
% -------  synthetic participant  185   -------
% -------  synthetic participant  186   -------
% -------  synthetic participant  187   -------
% -------  synthetic participant  188   -------
% -------  synthetic participant  189   -------
% -------  synthetic participant  190   -------
% -------  synthetic participant  191   -------
% -------  synthetic participant  192   -------
% -------  synthetic participant  193   -------
% -------  synthetic participant  194   -------
% -------  synthetic participant  195   -------
% -------  synthetic participant  196   -------
% -------  synthetic participant  197   -------
% -------  synthetic participant  198   -------
% -------  synthetic participant  199   -------
% -------  synthetic participant  200   -------
% -------  synthetic participant  201   -------
% -------  synthetic participant  202   -------
% -------  synthetic participant  203   -------
% -------  synthetic participant  204   -------
% -------  synthetic participant  205   -------
% -------  synthetic participant  206   -------
% -------  synthetic participant  207   -------
% -------  synthetic participant  208   -------
% -------  synthetic participant  209   -------
% -------  synthetic participant  210   -------
% -------  synthetic participant  211   -------
% -------  synthetic participant  212   -------
% -------  synthetic participant  213   -------
% -------  synthetic participant  214   -------
% -------  synthetic participant  215   -------
% -------  synthetic participant  216   -------
% -------  synthetic participant  217   -------
% -------  synthetic participant  218   -------
% -------  synthetic participant  219   -------
% -------  synthetic participant  220   -------
% -------  synthetic participant  221   -------
% -------  synthetic participant  222   -------
% -------  synthetic participant  223   -------
% -------  synthetic participant  224   -------
% -------  synthetic participant  225   -------
% -------  synthetic participant  226   -------
% -------  synthetic participant  227   -------
% -------  synthetic participant  228   -------
% -------  synthetic participant  229   -------
% -------  synthetic participant  230   -------
% -------  synthetic participant  231   -------
% -------  synthetic participant  232   -------
% -------  synthetic participant  233   -------
% -------  synthetic participant  234   -------
% -------  synthetic participant  235   -------
% -------  synthetic participant  236   -------
% -------  synthetic participant  237   -------
% -------  synthetic participant  238   -------
% -------  synthetic participant  239   -------
% -------  synthetic participant  240   -------
% -------  synthetic participant  241   -------
% -------  synthetic participant  242   -------
% -------  synthetic participant  243   -------
% -------  synthetic participant  244   -------
% -------  synthetic participant  245   -------
% -------  synthetic participant  246   -------
% -------  synthetic participant  247   -------
% -------  synthetic participant  248   -------
% -------  synthetic participant  249   -------
% -------  synthetic participant  250   -------
% -------  synthetic participant  251   -------
% -------  synthetic participant  252   -------
% -------  synthetic participant  253   -------
% -------  synthetic participant  254   -------
% -------  synthetic participant  255   -------
% -------  synthetic participant  256   -------
% -------  synthetic participant  257   -------
% -------  synthetic participant  258   -------
% -------  synthetic participant  259   -------
% -------  synthetic participant  260   -------
% -------  synthetic participant  261   -------
% -------  synthetic participant  262   -------
% -------  synthetic participant  263   -------
% -------  synthetic participant  264   -------
% -------  synthetic participant  265   -------
% -------  synthetic participant  266   -------
% -------  synthetic participant  267   -------
% -------  synthetic participant  268   -------
% -------  synthetic participant  269   -------
% -------  synthetic participant  270   -------
% -------  synthetic participant  271   -------
% -------  synthetic participant  272   -------
% -------  synthetic participant  273   -------
% -------  synthetic participant  274   -------
% -------  synthetic participant  275   -------
% -------  synthetic participant  276   -------
% -------  synthetic participant  277   -------
% -------  synthetic participant  278   -------
% -------  synthetic participant  279   -------
% -------  synthetic participant  280   -------
% -------  synthetic participant  281   -------
% -------  synthetic participant  282   -------
% -------  synthetic participant  283   -------
% -------  synthetic participant  284   -------
% -------  synthetic participant  285   -------
% -------  synthetic participant  286   -------
% -------  synthetic participant  287   -------
% -------  synthetic participant  288   -------
% -------  synthetic participant  289   -------
% -------  synthetic participant  290   -------
% -------  synthetic participant  291   -------
% -------  synthetic participant  292   -------
% -------  synthetic participant  293   -------
% -------  synthetic participant  294   -------
% -------  synthetic participant  295   -------
% -------  synthetic participant  296   -------
% -------  synthetic participant  297   -------
% -------  synthetic participant  298   -------
% -------  synthetic participant  299   -------
% -------  synthetic participant  300   -------

% %% [markdown]
% ## Estimation et visualisation des résultats
%
% Avec le processus ci-dessous nous avons obtenue:
% - les parametres utilisés pour engendre les choix du participant simulé ( -> les vrai paramètres)
% - les paramètres estimées par notre processus d'estimation des paramètres libres (-> les paramètres récuperées).
%
% Maintenant ce que nous allons faire, c'est evaluer de manière quantitative la correspondance entre les "vrai" paramètres et les paramètres récuperées par notre processus d'estimation. Concrètement, cela consiste dans une régression linaire (`glmfit`) dans la quelle nous prédisons les paramètres estimées par les vrai paramètres.
%
% Théoretiquement nous executons une régression lineaire simple:
%
% $$
% pestimatees = \beta_0 + \beta_1psimulees + \epsilon
% $$
%
% ou:
% - $pestimatees$ = variable dependante
% - $\beta_0$ = intercept de l'axe des Y de la droite de régression
% - $\beta_1$ = pente de la droite de régression
% - $psimulees$ = variable indépendante
% - $\epsilon $ = terme d'erreur (résidus)

% %% [markdown]
% ### Evaluation de l'estimation de la temperature
%
% Nous allons commencer par l'évaluation de la temperature. Premièrement on identifier les variables d'intérêt pour l'analyse dans la matrice dans la quelle on a sauvé nos résultats de l'étape précedante.

% %%
temp_simulee = simulated_param(:, 1);
temp_estimee = recovered_param(:, 1);

% %% [markdown]
% Maitenant nous pouvons executer la régression avec nos variables d'intérêt

% %%
[temp.b, ~, temp.stats]  = glmfit(temp_simulee, temp_estimee, 'normal');

% %% [markdown]
% Nous sommes dans un cas particulier dans lequel ce n'est pas la significativité qui nous intéresse spécialement.
%
% Pour comprendre les valeurs qui nous intéressent, nous allons utiliser une représentation visuelle. Nous allons illustrer:
% - des points qui illustrent les paramètres estimés en fonction des vrais paramètres
% - une droite pointillée qui montre la correspondance parfaite
% - la droite de régression que nous avons éstimée en rouge

% %%
figure % graphique intermediare

hold on 

% valeurs limites de la temperature
xl = [0 5]; 

% montrer la droite de régression = 1; correspondance parfaite
plot( xl, xl, ':k', 'LineWidth', 2); 

% montrer correlation entre les paramètres utilisées pour les simulations et les parametrèes estimées
plot( temp_simulee, temp_estimee, 'o', ...
        'MarkerFaceColor', [1, 1, 1], ...
        'MarkerEdgeColor', [0, 0, 0])

% montrer la droite de régression 
XX             = linspace(min(temp_estimee), max(temp_estimee), 1000);
[Yf, Yl, Yh]   = glmval(b, XX, 'identity', stats, 'confidence', 0.95);
XXX            = sortrows([XX', Yf, Yf-Yl, Yf+Yh], 1);
alpha(0.5)
plot(XXX(:,1), XXX(:,2), '-', 'Color', .5 * [1,0,0],'LineWidth', 2);

% montrer les titres des axes
xlabel(strcat('Temperature simulée'));
ylabel(strcat('Temperature estimée'));

% %% [markdown]
% Il y a trois aspects à evaluer:
% - la dispersion des points au tours de la droite pointilliées
% - la pente de la droite de régression rouge ($\beta_1$ estimée dans la regression)
% - l'intercept de la droite de régression rouge ($\beta_0$ estimée dans la regression)
%
%
% À fin de metter en evidence les deux derniers aspects nous pouvons faire un graphiques supplementaire qui illustre spécifiquement ces deux aspects:

% %%
figure

hold on
% montrer les barres et les barres d'erreur
bar(temp.stats.beta, 'FaceColor', .9 .* [1, 1, 1]);
errorbar(temp.stats.beta,temp.stats.se, 'k', 'LineStyle', 'none');
% montrer les noms des conditions dans l'axe x
set(gca,'YLim', [0 1], ...
        'XLim', [0 3], ...
        'XTick', [1 2], ...
        'XTickLabel', {'\beta_0','\beta_1'}, ...
        'FontSize', 12, ...
        'FontName', 'Arial')

% %% [markdown]
% Ici ce que nous voulons c'est un intercept ($\beta_0$) qui est proche de 0 et une pente ($\beta_1$) qui est proche de 1.

% %% [markdown]
% ### Grafique finale avec tout les résutatas
%
% Finalement nous pouvons créer un seul grafique avec plusieurs pannels qui resume l'information que nous avons vu dans les détails ci-dessous.

% %%
figure


%--------------------------------------------------------------------------------------------
% pannel 1 : Resultats pour la temperature 
%--------------------------------------------------------------------------------------------

% -------------- subpannel 1 droite de régression et points individuels
subplot(2, 2, 1) 
hold on

% limites des axes  
xl = [0 5];

% titres des axes
xlabel(strcat('Temperature simulée'));
ylabel(strcat('Temperature estimée'));

% recuper les variables d'intérêt
X = simulated_param(:, 1);
Y = recovered_param(:, 1);


% montrer la droite de régression = 1; correspondance parfaite
plot( xl, xl, ':k', 'LineWidth', 2); 

% montrer correlation entre les paramètres utilisées pour les simulations et les parametrèes estimées
plot( X(:), Y(:), 'o', ...
        'MarkerFaceColor', [1, 1, 1], ...
        'MarkerEdgeColor', [0, 0, 0])

% montrer la droite de régression 
[b, ~, stats]  = glmfit(X(:), Y(:), 'normal');
XX             = linspace(min(X(:)), max(X(:)), 1000);
[Yf, Yl, Yh]   = glmval(b, XX, 'identity', stats, 'confidence', 0.95);
XXX            = sortrows([XX', Yf, Yf-Yl, Yf+Yh], 1);
alpha(0.5)
plot(XXX(:,1), XXX(:,2), '-', 'Color', .5 * [1,0,0],'LineWidth', 2);


% -------------- subpannel 2 valuer de la régression
subplot(2, 2, 2) 

hold on
% montrer les barres et les barres d'erreur
bar(stats.beta, 'FaceColor', .9 .* [1, 1, 1])
errorbar(stats.beta,stats.se, 'k', 'LineStyle', 'none')
% montrer les noms des conditions dans l'axe x
set(gca,'YLim', [0 1], ...
        'XLim', [0 3], ...
        'XTick', [1 2], ...
        'XTickLabel', {'\beta_0','\beta_1'}, ...
        'FontSize', 12, ...
        'FontName', 'Arial')

%--------------------------------------------------------------------------------------------
% pannel 1 : alpha estimates
%--------------------------------------------------------------------------------------------


% -------------- subpannel 1 droite de régression et points individuels
subplot(2, 2, 3) 

hold on


xlabel(strcat('Taux d''apprentissage simulée'));
ylabel(strcat('Taux d''apprentissage estimée'));


X = simulated_param(:, 2);
Y = recovered_param(:, 2);

xl = [0 1];

% plot line r = 1
plot( xl, xl, ':k', 'LineWidth', 2);  

% plot correlation between estimated and simulated
plot( X(:), Y(:), 'o', 'MarkerFaceColor', [1, 1, 1], ...
        'MarkerEdgeColor', [0, 0, 0])

% compute the glm to plot the intrapolation line
[b, ~, stats]      = glmfit(X(:), Y(:), 'normal');
XX             = linspace(min(X(:)), max(X(:)), 1000);
[Yf, Yl, Yh]   = glmval(b, XX, 'identity', stats, 'confidence', 0.95);
XXX            = sortrows([XX', Yf, Yf-Yl, Yf+Yh], 1);
alpha(0.5)
plot(XXX(:,1), XXX(:,2), '-', 'Color', .5 * [1,0,0],'LineWidth', 2);


% -------------- subpannel 2 valuer de la régression
subplot(2, 2, 4) 

hold on

bar(stats.beta, 'FaceColor', .9 .* [1, 1, 1])
errorbar(stats.beta,stats.se, 'k', 'LineStyle', 'none')
set(gca,'YLim', [0 1], ...
        'XLim', [0 3], ...
        'XTick', [1 2], ...
        'XTickLabel', {'\beta_0','\beta_1'}, ...
        'FontSize', 12, ...
        'FontName', 'Arial')
